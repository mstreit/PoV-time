# %%
# %matplotlib inline

# %%
import numpy as np
np.random.seed(9221999)
import pandas as pd
from scipy import stats, optimize
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="Set2")

# %%
data = pd.read_table("data/influenza_usa_totalAvsB.tsv", "\t")

# %%
data
# Out:
#                             Date  1997 week: 1  1997 week: 2  1997 week: 3  \
# 0                  Total A and B           831           457           328
# 1                        Total A           791           439           294
# 2                        Total B            40            18            34
# 3  Number of specimens processed          2744          1921          1519
#
#    1997 week: 4  1997 week: 5  1997 week: 6  1997 week: 7  1997 week: 8  \
# 0           222           218           174           118           182
# 1           178           136           107            21            34
# 2            44            82            67            97           148
# 3          1284          1347          1408           941           148
#
#    1997 week: 9      ...       2014 week: 41  2014 week: 42  2014 week: 43  \
# 0           181      ...                 423            571            530
# 1            27      ...                 266            411            406
# ...

# %%
plt.figure(); data.iloc[0,280:].plot(); data.iloc[1,280:].plot(); data.iloc[2,280:].plot();

# %%
plt.figure(); data.iloc[0,20:70].plot(); data.iloc[1,20:70].plot(); data.iloc[2,20:70].plot();
