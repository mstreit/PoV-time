# %%
# %matplotlib inline

# %%
import numpy as np
np.random.seed(9221999)
import pandas as pd
from scipy import stats, optimize
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="Set2")

# %%
data = pd.read_table("data/influenza_usa_totalAvsB_52weeks_2007.tsv", "\t")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-166-10319d1b3492> in <module>()
# ----> 1 data = pd.read_table("data/influenza_usa_totalAvsB_52weeks_2007.tsv", "\t")
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# /Library/Python/2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:2966)()
#
# /Library/Python/2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5328)()
#
# IOError: File data/influenza_usa_totalAvsB_52weeks_2007.tsv does not exist

# %%
data
# Out:
#             Unnamed: 0  1997 week: 1  1997 week: 2  1997 week: 3  \
# 0  Specimens processed          2744          1921          1519
# 1        Total A and B           831           457           328
# 2              Total A           791           439           294
# 3              Total B            40            18            34
#
#    1997 week: 4  1997 week: 5  1997 week: 6  1997 week: 7  1997 week: 8  \
# 0          1284          1347          1408           941          1480
# 1           222           218           174           118           182
# 2           178           136           107            21            34
# 3            44            82            67            97           148
#
#    1997 week: 9      ...       2014 week: 41  2014 week: 42  2014 week: 43  \
# 0          1458      ...               10379          10976          10678
# 1           181      ...                 423            571            530
# 2            27      ...                 266            411            406
# 3           154      ...                 157            159            124
#
#    2014 week: 44  2014 week: 45  2014 week: 46  2014 week: 47  2014 week: 48  \
# 0          10885          12050          12938          15082          17142
# 1            707           1106           1313           2186           3289
# 2            575            956           1176           2030           3096
# 3            132            150            137            156            193
#
#    2014 week: 49  2014 week: 50
# 0          19373          20064
# 1           4407           5200
# 2           4184           5006
# 3            223            194
#
# [4 rows x 795 columns]

# %%
plt.figure()
#data.iloc[0,1:].plot() 
data.iloc[1,1:200].plot() 
data.iloc[2,1:200].plot()
data.iloc[3,1:200].plot()

# %%
mpl.rc("figure", figsize=(8, 4))
c1, c2, c3 = sns.color_palette("pastel", 3)

plot = sns.tsplot(data.iloc[1,1:53], color=c1)
#plot.set(xscale="linear", yscale="log")

sns.tsplot(data.iloc[1,1:52], color=c1)
sns.tsplot(data.iloc[1,53:104], color=c1)
sns.tsplot(data.iloc[1,105:156], color=c1)
sns.tsplot(data.iloc[1,157:208], color=c1)

sns.tsplot(data.iloc[2,1:52], color=c2)
sns.tsplot(data.iloc[2,53:104], color=c2)
sns.tsplot(data.iloc[2,105:156], color=c2)
sns.tsplot(data.iloc[2,157:208], color=c2)

sns.tsplot(data.iloc[3,1:52], color=c3)
sns.tsplot(data.iloc[3,53:104], color=c3)
sns.tsplot(data.iloc[3,105:156], color=c3)
sns.tsplot(data.iloc[3,157:208], color=c3)

# %%
c1, c2, c3 = sns.color_palette("pastel", 3)
offset = 0
weeks_a_year = 52

for x in range(0, 2):
    sns.tsplot(data.iloc[1,1 + weeks_a_year*x + offset : weeks_a_year*(x+1) + offset], color=c1)
    sns.tsplot(data.iloc[2,1 + weeks_a_year*x + offset : weeks_a_year*(x+1) + offset], color=c2)
    sns.tsplot(data.iloc[3,1 + weeks_a_year*x + offset : weeks_a_year*(x+1) + offset], color=c3)
