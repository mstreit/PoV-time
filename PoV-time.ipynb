# %%
# %matplotlib inline

# %%
import numpy as np
np.random.seed(9221999)
import pandas as pd
from scipy import stats, optimize
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="Set2")

# %%
data = pd.read_table("data/influenza_usa_totalAvsB_since2010.tsv", "\t")

# %%
data
# Out:
#                             Date  2010 week: 1  2010 week: 2  2010 week: 3  \
# 0                  Total A and B           366           396           447
# 1                        Total A           358           384           444
# 2                        Total B             8            12             3
# 3  Number of specimens processed            96          8678          8626
#
#    2010 week: 4  2010 week: 5  2010 week: 6  2010 week: 7  2010 week: 8  \
# 0           402           404           361           380           424
# 1           393           398           352           374           421
# 2             9             6             9             6             3
# 3          8622          8485           827          8463          8106
#
#    2010 week: 9      ...       2014 week: 41  2014 week: 42  2014 week: 43  \
# 0           445      ...                 423            571            530
# 1           440      ...                 266            411            406
# ...

# %%
plt.figure(); data.iloc[0,1:].plot(); data.iloc[1,1:].plot(); data.iloc[2,1:].plot();

# %%
mpl.rc("figure", figsize=(8, 4))
c1, c2, c3 = sns.color_palette("pastel", 3)

sns.tsplot(data.iloc[0,1:53], color=c1)
sns.tsplot(data.iloc[0,54:106], color=c1)
sns.tsplot(data.iloc[0,107:159], color=c1)
sns.tsplot(data.iloc[0,160:212], color=c1)

sns.tsplot(data.iloc[1,1:53], color=c2)
sns.tsplot(data.iloc[1,54:106], color=c2)
sns.tsplot(data.iloc[1,107:159], color=c2)
sns.tsplot(data.iloc[1,160:212], color=c2)

sns.tsplot(data.iloc[2,1:53], color=c3)
sns.tsplot(data.iloc[2,54:106], color=c3)
sns.tsplot(data.iloc[2,107:159], color=c3)
sns.tsplot(data.iloc[2,160:212], color=c3)

# %%
c1, c2, c3 = sns.color_palette("pastel", 3)

sns.tsplot(data.iloc[0,1+26:53+26], color=c1)
sns.tsplot(data.iloc[0,54+26:106+26], color=c1)
sns.tsplot(data.iloc[0,107+26:159+26], color=c1)
sns.tsplot(data.iloc[0,160+26:212+26], color=c1)

sns.tsplot(data.iloc[1,1+26:53+26], color=c2)
sns.tsplot(data.iloc[1,54+26:106+26], color=c2)
sns.tsplot(data.iloc[1,107+26:159+26], color=c2)
sns.tsplot(data.iloc[1,160+26:212+26], color=c2)

sns.tsplot(data.iloc[2,1+26:53+26], color=c3)
sns.tsplot(data.iloc[2,54+26:106+26], color=c3)
sns.tsplot(data.iloc[2,107+26:159+26], color=c3)
sns.tsplot(data.iloc[2,160+26:212+26], color=c3)

# %%
c1, c2, c3 = sns.color_palette("pastel", 3)

sns.tsplot(data.iloc[0,1+26:53+26], color=c1, interpolate='false')
sns.tsplot(data.iloc[0,54+26:106+26], color=c1, interpolate='false')
sns.tsplot(data.iloc[0,107+26:159+26], color=c1, interpolate='false')
sns.tsplot(data.iloc[0,160+26:212+26], color=c1, interpolate='false')

sns.tsplot(data.iloc[1,1+26:53+26], color=c2, interpolate='true')
sns.tsplot(data.iloc[1,54+26:106+26], color=c2, interpolate='true')
sns.tsplot(data.iloc[1,107+26:159+26], color=c2, interpolate='true')
sns.tsplot(data.iloc[1,160+26:212+26], color=c2, interpolate='true')

sns.tsplot(data.iloc[2,1+26:53+26], color=c3, interpolate='true')
sns.tsplot(data.iloc[2,54+26:106+26], color=c3, interpolate='true')
sns.tsplot(data.iloc[2,107+26:159+26], color=c3, interpolate='true')
sns.tsplot(data.iloc[2,160+26:212+26], color=c3, interpolate='true')
